# %%
from bs4 import BeautifulSoup
import requests
import csv
import pandas as pd

# %%
url="https://www.flipkart.com/search?q=laptops%20hp&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=on&as=off"

response = requests.get(url)

htmlcontent = response.content

soup = BeautifulSoup(htmlcontent,"html.parser")

print(soup.prettify)
# Out:
# <bound method Tag.prettify of <!DOCTYPE html>
# ...

# %%
products=[]

prices=[]

ratings=[]

low_high=[]

product=soup.find('div',attrs={'class':'_4rR01T'})

print(product.text)
# Out:
# HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (8 GB/512 GB SSD/Windows 11 Home/4 GB Graphics/NVIDIA GeF...

# %%
for a in soup.findAll('a',href=True, attrs={'class':'_1fQZEK'}):
    name=a.find('div',attrs={'class':'_4rR01T'})
    price=a.find('div',attrs={'class':'_30jeq3 _1_WHN1'})
    rating=a.find('div',attrs={'class':'_3LWZlK'})
    products.append(name.text)
    prices.append(price.text)
    ratings.append(rating.text)

# %%
import pandas as pd

df = pd.DataFrame({'Product Name':products,'Prices':prices,'Ratings':ratings,})
print(df)
# Out:
#                                          Product Name   Prices Ratings
# 0   HP Pavilion Ryzen 5 Hexa Core AMD R5-5600H - (...  ₹62,990     4.5
# 1   HP Intel Core i5 12th Gen - (8 GB/512 GB SSD/W...  ₹57,890     4.2
# 2   HP Intel Core i3 11th Gen - (8 GB/512 GB SSD/W...  ₹42,990     4.3
# 3   HP Intel Core i5 12th Gen - (16 GB/512 GB SSD/...  ₹61,999     4.1
# 4   HP Athlon Dual Core 3050U - (8 GB/512 GB SSD/W...  ₹29,990     4.2
# 5   HP Ryzen 5 Hexa Core 5500U - (8 GB/512 GB SSD/...  ₹48,890     4.3
# 6   HP Core i3 11th Gen - (8 GB/512 GB SSD/Windows...  ₹44,953     4.3
# 7   HP Athlon Dual Core 3050U - (8 GB/256 GB SSD/W...  ₹26,999     3.9
# 8   HP Ryzen 3 Dual Core 3250U - (8 GB/256 GB SSD/...  ₹29,499     4.1
# 9   HP Laptop with Backlit Keyboard Core i3 11th G...  ₹44,990     4.2
# 10  HP Pavilion Gaming Ryzen 7 Octa Core AMD R7-58...  ₹75,990     4.3
# 11  HP 15s Ryzen 3 Dual Core 3250U - (8 GB/1 TB HD...  ₹39,999     4.3
# ...

# %%
df.to_csv('task3.csv')
